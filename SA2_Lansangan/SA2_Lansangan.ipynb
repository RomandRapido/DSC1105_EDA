# %% [markdown]
# <div style="text-align: center;"> <h3>Exploratory Data Analysis</h3>
# <h5>Summative Assessment 2</h5>
# <h5>May 10, 2025</h5>
# <h5><u>By Romand Lansangan</u></h5>
#     </div>
#
# ---

# %% [markdown]
# ### Task Overview:
# You have a dataset containing the following features:
#
# * Customer ID (Unique Identifier)
#
# * Age (Continuous variable)
#
# * Annual Income (Continuous variable, in thousands of dollars)
#
# * Gender (Categorical: Male/Female)
#
# * Product Category Purchased (Categorical: Electronics, Fashion, Home, Books, Others)
#
# * Average Spend per Visit (Continuous variable, in dollars)
#
# * Number of Visits in Last 6 Months (Discrete variable)
#
# * Customer Segment (Categorical target variable: Budget Shopper, Regular Shopper, Premium Shopper)
#
# The target variable, Customer Segment, has three categories:
#
# * Budget Shopper (Low spenders)
#
# * Regular Shopper (Moderate spenders)
#
# * Premium Shopper (High spenders)

# %% [markdown]
# ### Load
# Import the dataset into R or Python.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("NSFG_2022_2023_FemRespPUFData.csv")
print(df.shape)
df.head()
# Out:
# (5586, 1912)
#    CaseID  RSCRAGE  RSCRNINF  RSCRHISP  RSCRRACE  FTFMODE DEVICE_TYPE  AGE_R  \
# 0   96064       29         5         5         3        2      Mobile     29
# 1   96066       18         5         1         4        2          PC     18
# 2   96068       37         1         5         2        2      Mobile     37
# 3   96071       40         1         5         3        2          PC     40
# 4   96072       49         1         5         2        2          PC     49
#
#    AGESCRN  HISP  ...  CMLSTYR  CMJAN3YR  CMJAN4YR  CMJAN5YR  CMFIVYR  YEAR  \
# 0       29     5  ...     1474      1441      1429      1417     1426     2
# 1       18     1  ...     1471      1441      1429      1417     1423     2
# 2       37     5  ...     1473      1441      1429      1417     1425     2
# 3       40     5  ...     1468      1441      1429      1417     1420     2
# 4       49     5  ...     1466      1441      1429      1417     1418     2
#
#    QUARTER  PHASE1  PHASE2  PHASE3
# 0        4       1       0       0
# 1        2       1       1       1
# 2        4       1       0       0
# 3        2       1       0       0
# 4        1       1       1       0
#
# [5 rows x 1912 columns]

# %% [markdown]
# Count variable:  `CONDSEXL` - Number of opposite-sex partners in lifetime for all types of sex (top-coded).
#
# Ordered categorical: `GRFSTSX` - Grade Respondent Was in at First Sexual Intercourse (bottom-coded).
#
# Categorical (nominal): `MANRASDU` - man Respondent thinks of as raised her during teens and `WOMRASDU` - woman Respondent thinks of as raised her during teens.
#
# Demographics: `LMARSTAT` - Respondent'slegal marital status relative to opposite-sex spouses.

# %%
df_var_desc = pd.read_csv("var_code.csv")

# %%
mapping = {'OPPLIFENUM' : "sex_partners", 
           'GRFSTSX': "first_sex" , 
           'MANRASDU': "man_guardian",
           'WOMRASDU': "woman_guardian",
           'LMARSTAT': 'marital_status'}
df_filtered = df[mapping.keys()].rename(mapping, axis=1).copy()
print(df_filtered.info())
df_filtered.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5586 entries, 0 to 5585
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sex_partners    4652 non-null   float64
#  1   first_sex       2513 non-null   float64
#  2   man_guardian    1733 non-null   float64
#  3   woman_guardian  1733 non-null   float64
#  4   marital_status  3486 non-null   float64
# dtypes: float64(5)
# memory usage: 218.3 KB
# None
#        sex_partners    first_sex  man_guardian  woman_guardian  marital_status
# count   4652.000000  2513.000000   1733.000000     1733.000000     3486.000000
# mean      72.732803    15.591325      2.316792        1.355453        5.751004
# std      246.206924    21.287587      1.258936        0.682612        0.687639
# min        1.000000     6.000000      1.000000        1.000000        3.000000
# 25%        2.000000     9.000000      1.000000        1.000000        6.000000
# 50%        5.000000    10.000000      2.000000        1.000000        6.000000
# 75%       10.000000    11.000000      3.000000        2.000000        6.000000
# max      999.000000    99.000000      8.000000        9.000000        9.000000

# %%
df_filtered.isna().sum()
# Out:
# sex_partners       934
# first_sex         3073
# man_guardian      3853
# woman_guardian    3853
# marital_status    2100
# dtype: int64

# %%
df_var_desc.columns
# Out:
# Index(['Variable Label', 'Variable Name', 'Variable Type'], dtype='object')

# %%
def print_desc(cols, df_desc):
    mask = df_desc['Variable Name'].isin(cols)
    for i, row in df_desc[mask].iterrows():
        print(f"{row['Variable Name']} : {row['Variable Label']}")

# %%
maska = df.isna().sum() == 0 

print_desc(mapping.keys(), df_var_desc)
# Out:
# LMARSTAT : AD-7c R's legal marital status relative to opposite-sex spouses
# WOMRASDU : AG-5 woman R thinks of as raised her during teens
# MANRASDU : AG-9 man R thinks of as raised her during teens
# GRFSTSX : CE-8 Grade R Was in at First Sexual Intercourse (bottom-coded)
# OPPLIFENUM : Number of opposite-sex partners in lifetime for all types of sex (computed in FC J-14d) (top-coded)

# %%
df_filtered['sex_partners'] = df_filtered['sex_partners'].fillna(0).astype(int)

mapping_marital = {
    3: "Widowed",
    4: "Divorced/annulled",
    5: "Separated",
    6: "Never married",
    8: "Refused",
    9: "Don't Know",
    None: "Married"
}
df_filtered['marital_status'] = df_filtered['marital_status'].map(mapping_marital)

mapping_sex = {
   6: "6-grade-less",
   7: "7-grade",
   8: "8-grade",
   9: "9-grade",
   10: "10-grade",
   11: "11-grade",
   12: "12-grade",
   13: "1-college",
   14: "2-college", 
   15: "3-college",
   16: "4-college",
   96: "Not-school",
   98: "Refused",
   99: "Don't know",
   None: "Inapplicable"
}
df_filtered['first_sex'] = df_filtered['first_sex'].map(mapping_sex)
df_filtered['first_sex'] = pd.Categorical(df_filtered.first_sex, categories=list(mapping_sex.values()), ordered=True)

mapping_man = {
   1: "Bio father",
   2: "Stepfather",
   3: "No father figure",
   4: "Other father figure",
   8: "Refused",
   None: "With both parents"
}
df_filtered['man_guardian'] = df_filtered['man_guardian'].map(mapping_man)


mapping_wom = {
   1: "Bio mother",
   2: "Other mother figure",
   3: "No mother figure",
   8: "Refused",
   9: "Don't know",
   None: "With both parents"
}
df_filtered['woman_guardian'] = df_filtered['woman_guardian'].map(mapping_wom)
df_filtered
# Out:
#       sex_partners     first_sex       man_guardian     woman_guardian  \
# 0                1  Inapplicable  With both parents  With both parents
# 1                0  Inapplicable  With both parents  With both parents
# 2                9      10-grade  With both parents  With both parents
# 3                8      11-grade  With both parents  With both parents
# 4                7       9-grade  With both parents  With both parents
# ...            ...           ...                ...                ...
# 5581             1  Inapplicable  With both parents  With both parents
# 5582             1  Inapplicable         Bio father         Bio mother
# 5583            15       8-grade  With both parents  With both parents
# 5584             1  Inapplicable         Bio father         Bio mother
# 5585             0  Inapplicable  With both parents  With both parents
#
#          marital_status
# 0         Never married
# 1         Never married
# 2         Never married
# 3               Married
# 4     Divorced/annulled
# ...                 ...
# 5581      Never married
# 5582            Married
# 5583            Married
# 5584      Never married
# 5585      Never married
#
# [5586 rows x 5 columns]

# %% [markdown]
# ## Exploration

# %%
sns.set_theme()
plt.rcParams['figure.facecolor'] = 'lightgrey'
plt.rcParams['axes.facecolor'] = 'lightgrey'

# %% [markdown]
# ### Missing Data

# %%
df_filtered.isna().sum()
# Out:
# sex_partners      0
# first_sex         0
# man_guardian      0
# woman_guardian    0
# marital_status    0
# dtype: int64

# %% [markdown]
# ### Data type

# %%
df_filtered.dtypes
# Out:
# sex_partners         int32
# first_sex         category
# man_guardian        object
# woman_guardian      object
# marital_status      object
# dtype: object

# %%
df_filtered.agg(['dtypes','nunique', 'unique']).T
# Out:
#                   dtypes nunique  \
# sex_partners       int32      48
# first_sex       category      15
# man_guardian      object       6
# woman_guardian    object       6
# marital_status    object       7
#
#                                                            unique
# sex_partners    [1, 0, 9, 8, 7, 4, 15, 13, 5, 999, 998, 3, 6, ...
# first_sex       ['Inapplicable', '10-grade', '11-grade', '9-gr...
# man_guardian    [With both parents, No father figure, Stepfath...
# woman_guardian  [With both parents, Bio mother, Other mother f...
# marital_status  [Never married, Married, Divorced/annulled, Se...

# %% [markdown]
# ### Distributions

# %%
cols = df_filtered.columns
rows = int(np.ceil(len(cols)/2))
fig, ax = plt.subplots(ncols=2, nrows=rows, figsize=(10,5*rows))
ax = ax.flatten()
for i, col in enumerate(cols):
    sns.countplot(
        df_filtered,
        y=col,
        hue=col,
        palette="viridis",
        ax=ax[i],
        legend=False
    )
    ax[i].tick_params(axis='y', labelsize=10)
    ax[i].set_ylabel('')
    ax[i].set_title(f"Distribution of {col.upper()}")

for i in range(len(cols) + 1):
    if i > len(cols) - 1:
        plt.delaxes(ax[i])

plt.tight_layout()

# %% [markdown]
# ---
#
# ### Poisson Regression

# %%
from sklearn.model_selection import train_test_split

mask = df_filtered.sex_partners < 998
df_filtered_pos = df_filtered[mask].copy()

df_train, df_test = train_test_split(
    df_filtered_pos, test_size=0.2, random_state=42
)

print("Train Set:", df_train.shape)
print("Test Set:", df_test.shape)
# Out:
# Train Set: (4223, 5)
# Test Set: (1056, 5)

# %%
def grouped(X, threshold, greater=True):
    if greater:
        if X >= threshold:
            return threshold
        else:
            return X
    else:
        if X <= threshold:
            return threshold
        else:
            return X

# %%
y_train = df_train.sex_partners.apply(lambda X : grouped(X, threshold=35)).plot(kind='hist') 
plt.title(r"Number of Sex Partners [Grouped $x\geq34$]");

# %%
dummy = pd.get_dummies(df_train[['man_guardian', 'woman_guardian']]) 
dummy.drop(columns=['man_guardian_With both parents', 'woman_guardian_Refused'], inplace=True)

# %%
def grouped(X, threshold, greater=True):
    if greater:
        if X >= threshold:
            return threshold
        else:
            return X
    else:
        if X <= threshold:
            return threshold
        else:
            return X
        
def wrangle(X, transformers={}):
    train_mode = len(transformers) == 0

    df_data = X.copy()

    mask = (df_data.sex_partners < 998) & (df_data['first_sex'].isin(['Refused', "Don't know"])==False)

    df_data = df_data[mask]

            
    df_data['sex_partners'] = df_data.sex_partners.apply(lambda X : grouped(X, threshold=35))

    dummy = pd.get_dummies(df_data[['man_guardian', 'woman_guardian']]) 
    dummy.drop(columns=['man_guardian_With both parents', 'woman_guardian_Refused'], inplace=True)

    sex_over_18 = (df_data['first_sex'] == "Inapplicable").rename("sex_over_18").astype(int)
    not_school = (df_data['first_sex'] == 'Not-school').rename("not_school").astype(int)
    education_mapping = {
    'Not-school': 0,
    '6-grade-less': 6,
    '7-grade': 7,
    '8-grade': 8,
    '9-grade': 9,
    '10-grade': 10,
    '11-grade': 11,
    '12-grade': 12,
    '1-college': 13,
    '2-college': 13,
    '3-college': 13,
    '4-college': 13,
    }
    first_sex_nom = df_data['first_sex'].map(education_mapping)

    dummy_marital = pd.get_dummies(df_data['marital_status'], drop_first=True, prefix="mar")

    impute_columns = ['first_sex', 'sex_over_18', 'not_school']

    impute = pd.concat([sex_over_18, not_school, first_sex_nom], axis=1)
    if train_mode:
        kernel = mf.ImputationKernel(
            data=impute.reset_index(drop=True),
            num_datasets=5,
            random_state=42
        )

        kernel.mice(5)
        imputed = kernel.complete_data().values
        imputed = pd.DataFrame(imputed, index=impute.index, columns=impute.columns)
        transformers['mi'] = kernel
    else:
        imputed = transformers['mi'].tranform(impute)
        imputed = pd.DataFrame(imputed, index=impute.index, columns=impute.columns)
    
    to_drop = ['man_guardian', 'woman_guardian', 'first_sex', 'marital_status']
    return pd.concat([df_data.drop(columns=to_drop), dummy, imputed, dummy_marital], axis=1)

# %%
testing = wrangle(df_train)

# %%
testing
# Out:
#       sex_partners  man_guardian_Bio father  man_guardian_No father figure  \
# 4812             1                    False                          False
# 2898             3                    False                          False
# 3864             9                    False                          False
# 1292             1                    False                          False
# 2183             0                    False                          False
# ...            ...                      ...                            ...
# 3254             5                    False                           True
# 3986             8                    False                          False
# 5490             0                    False                          False
# 5529             5                     True                          False
# 899              0                    False                          False
#
#       man_guardian_Other father figure  man_guardian_Refused  \
# 4812                             False                 False
# 2898                             False                 False
# 3864                             False                 False
# 1292                             False                 False
# 2183                             False                 False
# ...                                ...                   ...
# 3254                             False                 False
# 3986                              True                 False
# 5490                             False                 False
# 5529                             False                 False
# 899                              False                 False
#
#       man_guardian_Stepfather  woman_guardian_Bio mother  \
# 4812                    False                      False
# 2898                    False                      False
# 3864                    False                      False
# 1292                    False                      False
# 2183                    False                      False
# ...                       ...                        ...
# 3254                    False                       True
# 3986                    False                       True
# 5490                    False                      False
# 5529                    False                       True
# 899                     False                      False
#
#       woman_guardian_Don't know  woman_guardian_No mother figure  \
# 4812                      False                            False
# 2898                      False                            False
# 3864                      False                            False
# 1292                      False                            False
# 2183                      False                            False
# ...                         ...                              ...
# 3254                      False                            False
# 3986                      False                            False
# 5490                      False                            False
# 5529                      False                            False
# 899                       False                            False
#
#       woman_guardian_Other mother figure  woman_guardian_With both parents  \
# 4812                               False                              True
# 2898                               False                              True
# 3864                               False                              True
# 1292                               False                              True
# 2183                               False                              True
# ...                                  ...                               ...
# 3254                               False                             False
# 3986                               False                             False
# 5490                               False                              True
# 5529                               False                             False
# 899                                False                              True
#
#       sex_over_18  not_school  first_sex  mar_Don't Know  mar_Married  \
# 4812          0.0         0.0       11.0           False         True
# 2898          1.0         0.0        8.0           False         True
# 3864          1.0         0.0        9.0           False        False
# 1292          1.0         0.0       11.0           False         True
# 2183          1.0         0.0        9.0           False        False
# ...           ...         ...        ...             ...          ...
# 3254          0.0         0.0       10.0           False        False
# 3986          0.0         0.0       10.0           False        False
# 5490          1.0         0.0        9.0           False        False
# 5529          0.0         0.0       11.0           False         True
# 899           1.0         0.0       12.0           False        False
#
#       mar_Never married  mar_Refused  mar_Separated  mar_Widowed
# 4812              False        False          False        False
# 2898              False        False          False        False
# 3864              False        False          False        False
# 1292              False        False          False        False
# 2183               True        False          False        False
# ...                 ...          ...            ...          ...
# 3254              False        False          False        False
# 3986               True        False          False        False
# 5490               True        False          False        False
# 5529              False        False          False        False
# 899                True        False          False        False
#
# [4204 rows x 20 columns]

# %%
plt.figure(figsize=(15,15))
sns.heatmap(testing.corr(),annot=True, cmap="viridis", fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# ## Split
# Before making any modification to the data, let us split first to avoid any data leakage.

# %%
from sklearn.model_selection import train_test_split

df = pd.read_csv("customer_segmentation.csv")

df_train, df_test = train_test_split(
    df, test_size=0.2, random_state=42
)

print("Train Set:", df_train.shape)
print("Test Set:", df_test.shape)
# Out:
# Train Set: (8425, 8)
# Test Set: (2107, 8)

# %%
df_train_clean, transformer = wrangle(df_train)
print(df_train_clean.shape)

df_train_clean.columns
# Out:
# (8425, 10)
# Index(['Customer Segment', 'Age', 'Annual Income (K$)',
#        'Average Spend per Visit ($)', 'Number of Visits in Last 6 Months',
#        'IsMale', 'cat_Electronics', 'cat_Fashion', 'cat_Home', 'cat_Others'],
#       dtype='object')

# %%
df_test_clean, _ = wrangle(df_test, transformer)
print(df_test_clean.shape)
df_test_clean.columns
# Out:
# (2107, 10)
# Index(['Customer Segment', 'Age', 'Annual Income (K$)',
#        'Average Spend per Visit ($)', 'Number of Visits in Last 6 Months',
#        'IsMale', 'cat_Electronics', 'cat_Fashion', 'cat_Home', 'cat_Others'],
#       dtype='object')

# %% [markdown]
# ## Baseline

# %%
class_count = df_test_clean['Customer Segment'].value_counts(normalize=True).sort_values(ascending=False)
class_count
# Out:
# Customer Segment
# 1    0.354533
# 2    0.335074
# 0    0.310394
# Name: proportion, dtype: float64

# %%
baseline = class_count.iloc[0]
print("Majority Class will be the baseline:", baseline)
# Out:
# Majority Class will be the baseline: 0.35453251067869007

# %% [markdown]
# ## Model Building

# %%
from sklearn.linear_model import LogisticRegression

response="Customer Segment"
y_train = df_train_clean[response]
X_train = df_train_clean.drop(columns=response)
model = LogisticRegression(
    multi_class='multinomial',
    solver='lbfgs',
    penalty='l2', 
    C=1.0, 
    max_iter=1000 
)

model.fit(X_train, y_train)
# Out:
# d:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(max_iter=1000, multi_class='multinomial')

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(X_train)

accuracy_score(y_train, y_pred)
# Out:
# 0.3534718100890208

# %% [markdown]
# That's not a good accuracy considering the baseline is also around 0.35.

# %%
from sklearn.model_selection import GridSearchCV


model = LogisticRegression(
    solver='lbfgs',
    penalty='l2',
    max_iter=1000
)

param_grid = [
    {
        'solver': ['lbfgs', 'newton-cg', 'sag'],
        'penalty': ['l2'],
        'C': [0.001, 0.01, 0.1, 1, 10, 100]
    },
    {
        'solver': ['lbfgs', 'newton-cg', 'sag'],
        'penalty': [None]
    },
    {
        'solver': ['saga'],
        'penalty': ['l1', 'l2'],
        'C': [0.001, 0.01, 0.1, 1, 10, 100]
    },
     {
        'solver': ['saga'],
        'penalty': ['elasticnet'],
        'C': [0.001, 0.01, 0.1, 1, 10, 100],
        'l1_ratio': [0.2, 0.5, 0.8]
    },
    {
        'solver': ['saga'],
        'penalty': [None]
    }
]

grid_search = GridSearchCV(model, param_grid, cv=5)

grid_search.fit(X_train, y_train)

print(grid_search.best_params_)
print(grid_search.best_score_)

best_model = grid_search.best_estimator_
# Out:
# d:\Anaconda\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# d:\Anaconda\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# {'C': 0.01, 'l1_ratio': 0.5, 'penalty': 'elasticnet', 'solver': 'saga'}
# 0.3401780415430267

# %% [markdown]
# Still a horrible model!
#
# ## Model Evaluation

# %%
print("Baseline:", baseline)
# Out:
# Baseline: 0.35453251067869007

# %%
y_pred = best_model.predict(X_train)

print("Train accuracy:",accuracy_score(y_train, y_pred))
# Out:
# Train accuracy: 0.3397032640949555

# %%
y_test = df_test_clean[response]
X_test = df_test_clean.drop(columns=response)

y_pred = best_model.predict(X_test)

print("Test accuracy:",accuracy_score(y_test, y_pred))
# Out:
# Test accuracy: 0.3103939250118652

# %% [markdown]
# As we can see from the results, we would be better of with classifying everything as 1 or `Regular Shopper` since we would be right by about 35.45% of the time. This is better than the test accuracy of 31%.

# %%
from sklearn.metrics import log_loss
y_pred_proba = best_model.predict_proba(X_test)

logloss_score = log_loss(y_test, y_pred_proba)

print(f"Log Loss: {logloss_score}")
# Out:
# Log Loss: 1.0994688999518631

# %% [markdown]
# The log loss score just provides a quantitatiive basis that the model is performing **no better than random guessing**, or worse to some extent.

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(y_test,y_pred)
plt.title("Confusion Matrix of the Best Model");

# %% [markdown]
# According to the `Confusion Matrix of the Best Model`, everything was predicted as 0 or low spenders. This might be indicative of independence of the features to the response (which is obsevable by the `Correlational Heatmap` earlier).

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred, zero_division=True))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.31      1.00      0.47       654
#            1       1.00      0.00      0.00       747
#            2       1.00      0.00      0.00       706
#
#     accuracy                           0.31      2107
#    macro avg       0.77      0.33      0.16      2107
# weighted avg       0.79      0.31      0.15      2107

# %% [markdown]
# This classification report indicates a *degenerate result* where the model is predicting only class 0 for every single sample.
#
# *   **Recall for classes 1 and 2 is 0.00:** The model failed to correctly identify *any* instances of true class 1 or true class 2.
# *   **Recall for class 0 is 1.00:** The model correctly identified *all* instances of true class 0.
# *   **Precision for classes 1 and 2 is 1.00:** This is misleadingly high. It means that *when* the model predicted classes 1 or 2, it was always right. However, since the recall is 0, it means the model *never* predicted classes 1 or 2.
# *   **Precision for class 0 is 0.31:** When the model predicted class 0 (which it does for every sample), it was correct only 31% of the time.
# *   **Overall Accuracy is 0.31:** This matches the proportion of samples that are actually in class 0 (654 / 2107 ≈ 0.31), confirming that the model simply predicts class 0 universally.
# * **The only respectable score here is the f1-score with 0.47**: meaning, the model has correctly identified all the class 0. But commen sense tells us that's not gonna cut it because everything was classified as 0 in the first place.
#
# This result strongly suggests a fundamental problem with the model training or the features, as the model finds no signal to differentiate between class 0 and classes 1/2.

# %%
df_test_clean.columns
# Out:
# Index(['Customer Segment', 'Age', 'Annual Income (K$)',
#        'Average Spend per Visit ($)', 'Number of Visits in Last 6 Months',
#        'IsMale', 'cat_Electronics', 'cat_Fashion', 'cat_Home', 'cat_Others'],
#       dtype='object')

# %%
from scipy.stats import chi2_contingency

cats = [ 'IsMale', 'cat_Electronics', 'cat_Fashion', 'cat_Home', 'cat_Others']
results = []
for col in cats:
    contingency_table = pd.crosstab(df_train_clean[col], df_train_clean['Customer Segment'])
    chi2, p, dof, expected = chi2_contingency(contingency_table)

    results.append({
        "var" : col,
        "p-val" : p,
        "stats" : chi2,
        "is_independent" : p > 0.05
    })

pd.DataFrame(results)
# Out:
#                var     p-val     stats  is_independent
# 0           IsMale  0.147004  3.834596            True
# 1  cat_Electronics  0.935301  0.133774            True
# 2      cat_Fashion  0.344875  2.129147            True
# 3         cat_Home  0.606140  1.001287            True
# 4       cat_Others  0.466413  1.525368            True

# %%
from scipy.stats import kruskal
cols = ['Age', 'Annual Income (K$)',
       'Average Spend per Visit ($)', 
       'Number of Visits in Last 6 Months']
results = []
for col in cols:
    groups = [df_train_clean[df_train_clean[response] == seg][col] for seg in df_train_clean[response].unique()]
    kw_stat, p_kruskal = kruskal(*groups)
    results.append({
        "var" : col,
        "p-val" : p_kruskal,
        "stats" : kw_stat,
        "is_independent" : p > 0.05
    })

pd.DataFrame(results)
# Out:
#                                  var     p-val     stats  is_independent
# 0                                Age  0.243288  2.827019            True
# 1                 Annual Income (K$)  0.752990  0.567408            True
# 2        Average Spend per Visit ($)  0.404783  1.808810            True
# 3  Number of Visits in Last 6 Months  0.538345  1.238513            True

# %% [markdown]
# As we can see, both from chi-squere and kruskal test for independence, each feature is independent from the `Customer Segment`. This explain the horrible performance of the model.

# %%
best_model.get_params()
# Out:
# {'C': 0.01,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': 0.5,
#  'max_iter': 1000,
#  'multi_class': 'deprecated',
#  'n_jobs': None,
#  'penalty': 'elasticnet',
#  'random_state': None,
#  'solver': 'saga',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
pd.DataFrame(best_model.coef_.T, index=best_model.feature_names_in_)
# Out:
#                                           0         1    2
# Age                                0.000000  0.009454  0.0
# Annual Income (K$)                 0.000000  0.000000  0.0
# Average Spend per Visit ($)        0.001077  0.000000  0.0
# Number of Visits in Last 6 Months  0.000000  0.000000  0.0
# IsMale                             0.000000  0.000000  0.0
# cat_Electronics                    0.000000  0.000000  0.0
# cat_Fashion                        0.000000  0.000000  0.0
# cat_Home                           0.000000  0.000000  0.0
# cat_Others                         0.000000  0.000000  0.0

# %% [markdown]
# Besed on the feauture importance table above, all of the coeficients for 3 classes are 0. This means that *elasticnet* (which is an extension of both L1 and L2 regularization) found no useful linear relationship between the features and the response, except two predictors. Even then, they are still low and non-existend. No wonder the model predicted all the rows as 0 because no features will contribute to the calculations.

# %% [markdown]
# ---
#
# ## Feature Engineering
#
# ### Age Grouping

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

n_clusters = range(2,13)
inertia_errors = []
silhouette_scores = []
ss = StandardScaler()

X_scaled = ss.fit_transform(X_train[['Age']])
X_scaled_df = pd.DataFrame(X_scaled, columns=["Age"])

for k in n_clusters:
    model = KMeans(n_clusters=k, random_state=42)
    model.fit(X_scaled_df)
    inertia_errors.append(model.inertia_)
    silhouette_scores.append(silhouette_score(X_scaled, model.labels_))

# %%
intertia = np.array(inertia_errors)
mean_i = np.mean(intertia)
std_i = np.std(intertia)
stdz_i = (intertia - mean_i )/ std_i
stdz_i = stdz_i*-1

silhouette =   np.array(silhouette_scores)
mean_s = np.mean(silhouette)
std_s = np.std(silhouette)
stdz_s = (silhouette - mean_s )/ std_s

# %%
weight_inertia = 0.4
weight_silhouette = 0.6

combined_score = (weight_inertia * stdz_i) + (weight_silhouette * stdz_s)
result = pd.Series(combined_score).sort_values(ascending=False)
result.index = result.index + 2
result
# Out:
# 2     0.361475
# 3     0.338148
# 4     0.266864
# 5     0.204830
# 6    -0.019824
# 11   -0.089687
# 9    -0.103560
# 12   -0.170199
# 7    -0.201579
# 8    -0.254271
# 10   -0.332197
# dtype: float64

# %% [markdown]
# I think k=3 is more appropriate here for more granuality.

# %%
age_cluster = KMeans(n_clusters=3, random_state=42)
age_cluster.fit(X_scaled_df)
df_feat = df_train_clean.copy()
df_feat['age_cluster'] = age_cluster.labels_

# %% [markdown]
# ### Average Spend Cluster

# %%
def cluster_this(X, col):
    n_clusters = range(2,13)
    inertia_errors = []
    silhouette_scores = []
    ss = StandardScaler()

    X_scaled = ss.fit_transform(X[[col]])
    X_scaled_df = pd.DataFrame(X_scaled, columns=[col])

    for k in n_clusters:
        model = KMeans(n_clusters=k, random_state=42)
        model.fit(X_scaled_df)
        inertia_errors.append(model.inertia_)
        silhouette_scores.append(silhouette_score(X_scaled, model.labels_))
    
    intertia = np.array(inertia_errors)
    mean_i = np.mean(intertia)
    std_i = np.std(intertia)
    stdz_i = (intertia - mean_i )/ std_i
    stdz_i = stdz_i*-1

    silhouette =   np.array(silhouette_scores)
    mean_s = np.mean(silhouette)
    std_s = np.std(silhouette)
    stdz_s = (silhouette - mean_s )/ std_s

    weight_inertia = 0.4
    weight_silhouette = 0.6

    combined_score = (weight_inertia * stdz_i) + (weight_silhouette * stdz_s)
    result = pd.Series(combined_score).sort_values(ascending=False)
    result.index = result.index + 2

    return result

# %%
cluster_this(X_train, "Average Spend per Visit ($)")
# Out:
# 2     0.432346
# 4     0.349538
# 3     0.182226
# 5     0.067648
# 6    -0.033192
# 8    -0.055917
# 9    -0.088774
# 7    -0.095972
# 10   -0.178259
# 11   -0.286388
# 12   -0.293256
# dtype: float64

# %% [markdown]
# We can choose k=4

# %%
def label_this(X, col, k):
    ss = StandardScaler()

    X_scaled = ss.fit_transform(X_train[[col]])
    X_scaled_df = pd.DataFrame(X_scaled, columns=[col])

    cluster_model = KMeans(n_clusters=k, random_state=42)
    cluster_model.fit(X_scaled_df)
    return cluster_model.labels_

# %%
df_feat['spend_cluster'] = label_this(X_train, "Average Spend per Visit ($)", k=4)

# %% [markdown]
# ### Income

# %%
cluster_this(X_train, "Annual Income (K$)")
# Out:
# 2     0.402144
# 3     0.305105
# 5     0.197796
# 4     0.196621
# 6     0.015347
# 7    -0.125152
# 9    -0.141712
# 8    -0.156708
# 10   -0.175433
# 12   -0.258901
# 11   -0.259108
# dtype: float64

# %% [markdown]
# Let's choose k=3.

# %%
df_feat['income_cluster'] = label_this(X_train, "Annual Income (K$)", k=3)

# %%
cols = np.array(['age_cluster', 'spend_cluster', 'income_cluster'])

dummies = []
combinations = []
for col in cols:
    dum = pd.get_dummies(df_feat[col], prefix=col)
    dummies.append(dum)

for i, col in enumerate(cols):
    for j in range(len(cols)):
        if i == j:
            continue
        temp_dum_1 = dummies[i] # the first term
        temp_dum_2 = dummies[j] # the second tem

        for x, col_1 in enumerate(temp_dum_1.columns):
            for y, col_2 in enumerate(temp_dum_2.columns):
                name = f"{col_1}*{col_2}"
                mult = (temp_dum_1.iloc[:,x] * temp_dum_2.iloc[:,y]).rename(name)
                combinations.append(mult)

df_combinations = pd.concat(combinations, axis=1)
df_dummies = pd.concat(dummies, axis=1)

# %%
df_feat_fin = pd.concat([df_feat.drop(columns=cols), df_dummies,  df_combinations], axis=1)
df_feat_fin
# Out:
#       Customer Segment       Age  Annual Income (K$)  \
# 1263                 1 -0.579976            1.504988
# 1618                 0  1.236041           -0.178305
# 8612                 1 -1.454354            1.475966
# 5405                 2 -1.118055           -0.323417
# 9875                 1  1.505080            1.534010
# ...                ...       ...                 ...
# 5734                 2  1.034261           -0.004172
# 5191                 0  0.361663           -0.787774
# 5390                 2 -0.310936           -0.323417
# 860                  2  0.496182           -1.165064
# 7270                 0 -0.176416            0.634319
#
#       Average Spend per Visit ($)  Number of Visits in Last 6 Months  IsMale  \
# 1263                    -0.440189                           1.490859       1
# 1618                     0.084677                          -1.382147       1
# 8612                     0.260772                           1.490859       0
# 5405                     0.270115                          -0.490525       0
# 9875                    -1.077013                           0.302029       1
# ...                           ...                                ...     ...
# 5734                     1.579004                           0.401098       0
# 5191                    -1.041375                          -0.787732       1
# 5390                    -1.216592                           0.896444       1
# 860                     -0.947127                           0.995513       0
# 7270                    -0.293336                           1.490859       0
#
#       cat_Electronics  cat_Fashion  cat_Home  cat_Others  ...  \
# 1263                0            0         1           0  ...
# 1618                0            0         1           0  ...
# 8612                0            1         0           0  ...
# 5405                1            0         0           0  ...
# 9875                0            0         0           1  ...
# ...               ...          ...       ...         ...  ...
# 5734                0            0         0           0  ...
# 5191                0            1         0           0  ...
# 5390                0            0         0           1  ...
# 860                 0            0         0           0  ...
# 7270                1            0         0           0  ...
#
#       income_cluster_0*spend_cluster_2  income_cluster_0*spend_cluster_3  \
# 1263                              True                             False
# 1618                             False                             False
# 8612                             False                             False
# 5405                             False                             False
# 9875                             False                             False
# ...                                ...                               ...
# 5734                             False                             False
# 5191                             False                             False
# 5390                             False                             False
# 860                              False                             False
# 7270                              True                             False
#
#       income_cluster_1*spend_cluster_0  income_cluster_1*spend_cluster_1  \
# 1263                             False                             False
# 1618                             False                             False
# 8612                             False                             False
# 5405                             False                             False
# 9875                             False                             False
# ...                                ...                               ...
# 5734                             False                             False
# 5191                             False                              True
# 5390                             False                             False
# 860                              False                              True
# 7270                             False                             False
#
#       income_cluster_1*spend_cluster_2  income_cluster_1*spend_cluster_3  \
# 1263                             False                             False
# 1618                             False                             False
# 8612                             False                             False
# 5405                             False                             False
# 9875                             False                             False
# ...                                ...                               ...
# 5734                             False                             False
# 5191                             False                             False
# 5390                             False                             False
# 860                              False                             False
# 7270                             False                             False
#
#       income_cluster_2*spend_cluster_0  income_cluster_2*spend_cluster_1  \
# 1263                             False                             False
# 1618                              True                             False
# 8612                             False                             False
# 5405                              True                             False
# 9875                             False                             False
# ...                                ...                               ...
# 5734                             False                             False
# 5191                             False                             False
# 5390                             False                              True
# 860                              False                             False
# 7270                             False                             False
#
#       income_cluster_2*spend_cluster_2  income_cluster_2*spend_cluster_3
# 1263                             False                             False
# 1618                             False                             False
# 8612                             False                             False
# 5405                             False                             False
# 9875                             False                             False
# ...                                ...                               ...
# 5734                             False                              True
# 5191                             False                             False
# 5390                             False                             False
# 860                              False                             False
# 7270                             False                             False
#
# [8425 rows x 86 columns]

# %% [markdown]
# Spend / Income
#
# Frequent Visitors and HIgh Spenders

# %%
df_feat_fin['spent/income'] = df_feat_fin['Average Spend per Visit ($)'] / df_feat_fin['Annual Income (K$)']

df_feat_fin['average_spent_last_6_months'] = df_feat_fin['Average Spend per Visit ($)'] * df_feat_fin['Number of Visits in Last 6 Months']

df_feat_fin['1_year_spending_proportion_phase'] = df_feat_fin['average_spent_last_6_months'] * 2 / df_feat_fin['Annual Income (K$)']

# %%
plt.figure(figsize=(20,10))

sns.heatmap(
    df_feat_fin.corr(),
    cmap="viridis"
)

plt.title("Correlation Heatmap");

# %%
response = "Customer Segment"
y_train = df_feat_fin[response]
X_train = df_feat_fin.drop(columns=response)

scaler_l1 = StandardScaler()
X_train_scaled_l1 = scaler_l1.fit_transform(X_train)

model_l1 = LogisticRegression(penalty='l1', solver='liblinear', C=1.0, random_state=42)
model_l1.fit(X_train_scaled_l1, y_train)


coefficients_l1 = pd.DataFrame({'Feature': X_train.columns, 'Coefficient': model_l1.coef_[0]})
print(f"\nNumber of non-zero coefficients: {np.sum(model_l1.coef_[0] != 0)}")
coefs = coefficients_l1[coefficients_l1['Coefficient'] != 0].sort_values(by='Coefficient', ascending=False).reset_index(drop=True)
coefs
# Out:
# Number of non-zero coefficients: 56
#                               Feature   Coefficient
# 0      income_cluster_0*age_cluster_0  5.182473e-02
# 1         average_spent_last_6_months  3.008032e-02
# 2                              IsMale  2.699110e-02
# 3         Average Spend per Visit ($)  2.663757e-02
# 4    income_cluster_0*spend_cluster_2  2.611614e-02
# 5                        spent/income  2.530695e-02
# 6   Number of Visits in Last 6 Months  2.293341e-02
# 7    spend_cluster_1*income_cluster_2  1.580050e-02
# 8    income_cluster_0*spend_cluster_3  1.489077e-02
# 9    income_cluster_1*spend_cluster_0  1.443570e-02
# 10   income_cluster_2*spend_cluster_1  9.835638e-03
# 11   spend_cluster_0*income_cluster_1  9.334173e-03
# 12   spend_cluster_2*income_cluster_0  9.213998e-03
# 13     age_cluster_2*income_cluster_1  9.090563e-03
# 14      age_cluster_2*spend_cluster_2  7.882959e-03
# 15     income_cluster_0*age_cluster_1  6.097527e-03
# 16     age_cluster_0*income_cluster_0  5.515011e-03
# 17      spend_cluster_0*age_cluster_0  3.619437e-03
# 18     income_cluster_1*age_cluster_2  3.344361e-03
# 19     age_cluster_1*income_cluster_0  3.322183e-03
# 20   spend_cluster_3*income_cluster_0  3.112938e-03
# 21      spend_cluster_2*age_cluster_2  2.422673e-03
# 22                    spend_cluster_0  1.392290e-03
# 23     income_cluster_2*age_cluster_0  8.689277e-04
# 24     age_cluster_0*income_cluster_2  4.679138e-04
# 25      age_cluster_0*spend_cluster_0  6.753490e-05
# 26     age_cluster_2*income_cluster_2 -4.716852e-07
# 27      age_cluster_1*spend_cluster_2 -1.003661e-04
# 28   income_cluster_0*spend_cluster_1 -4.009073e-04
# 29   spend_cluster_1*income_cluster_0 -4.478032e-04
# 30      age_cluster_1*spend_cluster_1 -5.995487e-04
# 31      spend_cluster_3*age_cluster_2 -1.233623e-03
# 32      spend_cluster_3*age_cluster_0 -2.129486e-03
# 33   spend_cluster_1*income_cluster_1 -2.292464e-03
# 34      age_cluster_2*spend_cluster_3 -2.358451e-03
# 35   income_cluster_2*spend_cluster_3 -2.717332e-03
# 36      age_cluster_0*spend_cluster_3 -2.845597e-03
# 37     income_cluster_2*age_cluster_2 -3.510611e-03
# 38     income_cluster_1*age_cluster_0 -3.907107e-03
# 39   spend_cluster_3*income_cluster_1 -5.315912e-03
# 40     income_cluster_2*age_cluster_1 -6.412753e-03
# 41   spend_cluster_3*income_cluster_2 -6.415911e-03
# 42   income_cluster_2*spend_cluster_2 -8.501885e-03
# 43      spend_cluster_1*age_cluster_1 -9.299626e-03
# 44   1_year_spending_proportion_phase -9.621884e-03
# 45                                Age -1.372835e-02
# 46   spend_cluster_2*income_cluster_2 -1.588123e-02
# 47      spend_cluster_2*age_cluster_1 -1.695994e-02
# 48   income_cluster_1*spend_cluster_3 -1.825045e-02
# 49     age_cluster_0*income_cluster_1 -2.881434e-02
# 50   income_cluster_1*spend_cluster_1 -3.106247e-02
# 51                    cat_Electronics -4.048636e-02
# 52                           cat_Home -4.138455e-02
# 53                 Annual Income (K$) -4.703574e-02
# 54                         cat_Others -5.757133e-02
# 55                        cat_Fashion -6.582841e-02

# %%
cor = df_feat_fin[coefs.Feature].corr().stack().reset_index()
mask = (cor['level_0'] != cor['level_1']) & (cor[0] == 1)
cor[mask]
# Out:
#                                level_0                           level_1    0
# 16      income_cluster_0*age_cluster_0    age_cluster_0*income_cluster_0  1.0
# 236   income_cluster_0*spend_cluster_2  spend_cluster_2*income_cluster_0  1.0
# 402   spend_cluster_1*income_cluster_2  income_cluster_2*spend_cluster_1  1.0
# 468   income_cluster_0*spend_cluster_3  spend_cluster_3*income_cluster_0  1.0
# 515   income_cluster_1*spend_cluster_0  spend_cluster_0*income_cluster_1  1.0
# 567   income_cluster_2*spend_cluster_1  spend_cluster_1*income_cluster_2  1.0
# 625   spend_cluster_0*income_cluster_1  income_cluster_1*spend_cluster_0  1.0
# 676   spend_cluster_2*income_cluster_0  income_cluster_0*spend_cluster_2  1.0
# 746     age_cluster_2*income_cluster_1    income_cluster_1*age_cluster_2  1.0
# 805      age_cluster_2*spend_cluster_2     spend_cluster_2*age_cluster_2  1.0
# 859     income_cluster_0*age_cluster_1    age_cluster_1*income_cluster_0  1.0
# 896     age_cluster_0*income_cluster_0    income_cluster_0*age_cluster_0  1.0
# 977      spend_cluster_0*age_cluster_0     age_cluster_0*spend_cluster_0  1.0
# 1021    income_cluster_1*age_cluster_2    age_cluster_2*income_cluster_1  1.0
# 1079    age_cluster_1*income_cluster_0    income_cluster_0*age_cluster_1  1.0
# 1128  spend_cluster_3*income_cluster_0  income_cluster_0*spend_cluster_3  1.0
# 1190     spend_cluster_2*age_cluster_2     age_cluster_2*spend_cluster_2  1.0
# 1312    income_cluster_2*age_cluster_0    age_cluster_0*income_cluster_2  1.0
# 1367    age_cluster_0*income_cluster_2    income_cluster_2*age_cluster_0  1.0
# 1417     age_cluster_0*spend_cluster_0     spend_cluster_0*age_cluster_0  1.0
# 1493    age_cluster_2*income_cluster_2    income_cluster_2*age_cluster_2  1.0
# 1559     age_cluster_1*spend_cluster_2     spend_cluster_2*age_cluster_1  1.0
# 1597  income_cluster_0*spend_cluster_1  spend_cluster_1*income_cluster_0  1.0
# 1652  spend_cluster_1*income_cluster_0  income_cluster_0*spend_cluster_1  1.0
# 1723     age_cluster_1*spend_cluster_1     spend_cluster_1*age_cluster_1  1.0
# 1770     spend_cluster_3*age_cluster_2     age_cluster_2*spend_cluster_3  1.0
# 1828     spend_cluster_3*age_cluster_0     age_cluster_0*spend_cluster_3  1.0
# 1898  spend_cluster_1*income_cluster_1  income_cluster_1*spend_cluster_1  1.0
# 1935     age_cluster_2*spend_cluster_3     spend_cluster_3*age_cluster_2  1.0
# 2001  income_cluster_2*spend_cluster_3  spend_cluster_3*income_cluster_2  1.0
# 2048     age_cluster_0*spend_cluster_3     spend_cluster_3*age_cluster_0  1.0
# 2098    income_cluster_2*age_cluster_2    age_cluster_2*income_cluster_2  1.0
# 2177    income_cluster_1*age_cluster_0    age_cluster_0*income_cluster_1  1.0
# 2232  spend_cluster_3*income_cluster_1  income_cluster_1*spend_cluster_3  1.0
# 2331  spend_cluster_3*income_cluster_2  income_cluster_2*spend_cluster_3  1.0
# 2398  income_cluster_2*spend_cluster_2  spend_cluster_2*income_cluster_2  1.0
# 2438     spend_cluster_1*age_cluster_1     age_cluster_1*spend_cluster_1  1.0
# 2618  spend_cluster_2*income_cluster_2  income_cluster_2*spend_cluster_2  1.0
# 2659     spend_cluster_2*age_cluster_1     age_cluster_1*spend_cluster_2  1.0
# 2727  income_cluster_1*spend_cluster_3  spend_cluster_3*income_cluster_1  1.0
# 2782    age_cluster_0*income_cluster_1    income_cluster_1*age_cluster_0  1.0
# 2833  income_cluster_1*spend_cluster_1  spend_cluster_1*income_cluster_1  1.0

# %%
coefs_rank = np.argsort(abs(coefs['Coefficient'].values))[::-1]
rank = coefs.iloc[coefs_rank].reset_index(drop=True)

# %%
rank = coefs.iloc[coefs_rank].reset_index(drop=True)
rank.head()
# Out:
#                           Feature  Coefficient
# 0                     cat_Fashion    -0.065828
# 1                      cat_Others    -0.057571
# 2  income_cluster_0*age_cluster_0     0.051825
# 3              Annual Income (K$)    -0.047036
# 4                        cat_Home    -0.041385

# %%
def find_rank(X, rank):
    label_1 = X['level_0']
    label_2 = X['level_1']

    ranking_1 = rank[label_1 == rank['Feature']].index
    ranking_2 = rank[label_2 == rank['Feature']].index
    
    return ranking_1, ranking_2

# %%
mul_col = cor[mask].copy()

def find_rank(X, rank):
    label_1 = X['level_0']
    label_2 = X['level_1']

    ranking_1 = rank.index[rank['Feature'] == label_1].values[0]
    ranking_2 = rank.index[rank['Feature'] == label_2].values[0]
    
    return [ranking_1, ranking_2]

mul_col[["level_0_ranking", "level_1_ranking"]] = mul_col.apply(
    lambda X: find_rank(X, rank),
    axis=1,
    result_type='expand'
)

mul_col.head()
# Out:
#                               level_0                           level_1    0  \
# 16     income_cluster_0*age_cluster_0    age_cluster_0*income_cluster_0  1.0
# 236  income_cluster_0*spend_cluster_2  spend_cluster_2*income_cluster_0  1.0
# 402  spend_cluster_1*income_cluster_2  income_cluster_2*spend_cluster_1  1.0
# 468  income_cluster_0*spend_cluster_3  spend_cluster_3*income_cluster_0  1.0
# 515  income_cluster_1*spend_cluster_0  spend_cluster_0*income_cluster_1  1.0
#
#      level_0_ranking  level_1_ranking
# 16                 2               32
# 236               11               25
# 402               17               21
# 468               18               39
# 515               19               23

# %%
del mul_col[0]

# %%
len(mul_col) - mul_col['level_0_ranking'].nunique()
# Out:
# 0

# %%
len(mul_col) - mul_col['level_1_ranking'].nunique()
# Out:
# 0

# %% [markdown]
# All rankings are unique.

# %%
def lower_rank(X):
    if X['level_0_ranking'] <  X['level_1_ranking']: 
        return X['level_1']
    else:
        return X['level_0']
    

mul_col['to_drop'] = mul_col.apply(lambda X: lower_rank(X), axis=1)

# %%
no_mul_col =  df_feat_fin[coefs.Feature].drop(columns=mul_col['to_drop'].to_list())
print(no_mul_col.shape)
# Out:
# (8425, 35)

# %%
plt.figure(figsize=(20,10))

sns.heatmap(
    no_mul_col.corr(),
    cmap="viridis"
)

plt.title("Correlation Heatmap After Feature selection", size=20);

# %% [markdown]
# ## Another Modeling

# %%
from sklearn.model_selection import GridSearchCV

X_train, y_train = no_mul_col, df_feat_fin[response]

model = LogisticRegression(max_iter=10000)

param_grid = [
    {
        'solver': ['lbfgs', 'newton-cg', 'sag'],
        'penalty': ['l2'],
        'C': [0.001, 0.01, 0.1, 1, 10, 100]
    },
    {
        'solver': ['lbfgs', 'newton-cg', 'sag'],
        'penalty': [None]
    },
    {
        'solver': ['saga'],
        'penalty': ['l1', 'l2'],
        'C': [0.001, 0.01, 0.1, 1, 10, 100]
    },
     {
        'solver': ['saga'],
        'penalty': ['elasticnet'],
        'C': [0.001, 0.01, 0.1, 1, 10, 100],
        'l1_ratio': [0.2, 0.5, 0.8]
    },
    {
        'solver': ['saga'],
        'penalty': [None]
    }
]

grid_search = GridSearchCV(model, param_grid, cv=5, verbose=1)

grid_search.fit(X_train, y_train)

print(grid_search.best_params_)
print(grid_search.best_score_)

best_model = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 52 candidates, totalling 260 fits
# {'C': 0.001, 'l1_ratio': 0.5, 'penalty': 'elasticnet', 'solver': 'saga'}
# 0.343620178041543

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(random_state=42)
clf.fit(X=X_train, y=y_train)
acc_train = accuracy_score(y_train, clf.predict(X_train))
acc_train
# Out:
# RandomForestClassifier(random_state=42)

# %%
from sklearn.metrics import accuracy_score

acc_train = accuracy_score(y_train, clf.predict(X_train))
acc_train
# Out:
# 1.0

# %%
pd.Series(clf.feature_importances_, index=clf.feature_names_in_).sort_values(ascending=False)
# Out:
# Average Spend per Visit ($)          0.126519
# average_spent_last_6_months          0.126157
# spent/income                         0.124354
# 1_year_spending_proportion_phase     0.122897
# Annual Income (K$)                   0.111042
# Age                                  0.108446
# Number of Visits in Last 6 Months    0.098233
# IsMale                               0.024153
# cat_Electronics                      0.017732
# cat_Home                             0.017305
# cat_Others                           0.017296
# cat_Fashion                          0.016312
# spend_cluster_0                      0.005942
# income_cluster_2*age_cluster_0       0.005430
# income_cluster_2*age_cluster_1       0.005382
# income_cluster_2*age_cluster_2       0.005190
# age_cluster_0*income_cluster_1       0.005102
# income_cluster_0*age_cluster_1       0.004534
# age_cluster_2*income_cluster_1       0.004486
# income_cluster_0*age_cluster_0       0.004417
# spend_cluster_0*age_cluster_0        0.003960
# spend_cluster_1*age_cluster_1        0.003827
# spend_cluster_2*age_cluster_1        0.003809
# spend_cluster_2*income_cluster_2     0.003781
# age_cluster_0*spend_cluster_3        0.003679
# age_cluster_2*spend_cluster_2        0.003452
# age_cluster_2*spend_cluster_3        0.003413
# spend_cluster_1*income_cluster_2     0.003307
# income_cluster_0*spend_cluster_2     0.003072
# spend_cluster_3*income_cluster_2     0.003055
# income_cluster_1*spend_cluster_0     0.002950
# spend_cluster_1*income_cluster_0     0.002800
# income_cluster_1*spend_cluster_1     0.002769
# income_cluster_0*spend_cluster_3     0.002703
# income_cluster_1*spend_cluster_3     0.002496
# dtype: float64

# %%
df_train_clean_add =  df_train_clean.copy()
df_train_clean_add['spent/income'] = df_train_clean_add['Average Spend per Visit ($)'] / df_train_clean_add['Annual Income (K$)']
df_train_clean_add['average_spent_last_6_months'] = df_train_clean_add['Average Spend per Visit ($)'] * df_train_clean_add['Number of Visits in Last 6 Months']
df_train_clean_add['1_year_spending_proportion_phase'] = df_train_clean_add['average_spent_last_6_months'] * 2 / df_train_clean_add['Annual Income (K$)']

X_train, y_train = df_train_clean_add.drop(columns=response), df_train_clean_add[response]

# %%
clf = RandomForestClassifier(random_state=42)
clf.fit(X=X_train, y=y_train)
acc_train = accuracy_score(y_train, clf.predict(X_train))
acc_train
# Out:
# 1.0

# %%
df_test_clean_add =  df_test_clean.copy()
df_test_clean_add['spent/income'] = df_test_clean_add['Average Spend per Visit ($)'] / df_test_clean_add['Annual Income (K$)']
df_test_clean_add['average_spent_last_6_months'] = df_test_clean_add['Average Spend per Visit ($)'] * df_test_clean_add['Number of Visits in Last 6 Months']
df_test_clean_add['1_year_spending_proportion_phase'] = df_test_clean_add['average_spent_last_6_months'] * 2 / df_test_clean_add['Annual Income (K$)']

X_test, y_test = df_test_clean_add.drop(columns=response), df_test_clean_add[response]

# %%
acc_test = accuracy_score(y_test, clf.predict(X_test))
acc_test
# Out:
# 0.32558139534883723

# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score, classification_report



pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('rf', RandomForestClassifier(random_state=42))
])

param_grid = {
    'rf__n_estimators': [100, 200, 500],
    'rf__max_features': ['sqrt', 'log2', None],
    'rf__max_depth': [10, 20, None],
    'rf__min_samples_split': [2, 5, 10],
    'rf__min_samples_leaf': [1, 2, 4],
    'rf__bootstrap': [True],
    'rf__criterion': ['gini', 'entropy'],
}

grid_search = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    scoring='accuracy',
    cv=5,
    n_jobs=-1,
    verbose=2
)

print("Starting Grid Search...")
grid_search.fit(X_train, y_train)
print("Grid Search Complete.")

print("\nBest parameters found:")
print(grid_search.best_params_)

print("\nBest cross-validation score (on training data folds):")
print(grid_search.best_score_)

best_model = grid_search.best_estimator_

test_score = best_model.score(X_test, y_test)
print(f"\nScore on the test set: {test_score:.4f}")

y_pred = best_model.predict(X_test)
print("\nClassification Report on Test Set:")
print(classification_report(y_test, y_pred))
# Out:
# Starting Grid Search...
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Grid Search Complete.
#
# Best parameters found:
# {'rf__bootstrap': True, 'rf__criterion': 'entropy', 'rf__max_depth': 20, 'rf__max_features': 'sqrt', 'rf__min_samples_leaf': 2, 'rf__min_samples_split': 10, 'rf__n_estimators': 100}
#
# Best cross-validation score (on training data folds):
# 0.338160237388724
#
# Score on the test set: 0.3218
#
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#            0       0.30      0.37      0.33       654
#            1       0.33      0.29      0.31       747
#            2       0.34      0.32      0.33       706
#
#     accuracy                           0.32      2107
#    macro avg       0.32      0.32      0.32      2107
# weighted avg       0.32      0.32      0.32      2107

# %% [markdown]
# Even in random forest. There stil no luck. Nonetheless, let's report the intiatial model.

# %% [markdown]
# ---
#
# ## Reporting
#
# The logistic linear model did not brought forth any useful result given the limited dataset. The dataset was behaved and were approximately normal so there existed no necessity for strict transformation. This was also the case for all the distribution if grouped by the response variable, that is `Customer Segmentation`. The categorical variables was handled appropriately with `Gender` turned to `IsMale` for binary classification and `Product Category Purchased` one-hot encoded. The continous variable were all transformed by calculating their z-score for scaling reason. Then the data was split into two sets, train and test set with 80:20 ratio. An initial baseline was calculated using the normalized frequency of the majority class that is the class 1 or "Regular Spenders" with 0.354533.
#
# After all that, initial logistic model regression was trained that resulted to a train accuracy of approximately 0.3535. Which is simillar to baseline. Given that this was the training score, the test result will most likely be lower. So, it could be asserted that this was not a good model. Hyperparameter tuning was done to see if the results could be improved. The best model for the tuning brought worse results with an accuracy training score of 0.3397032640949555, test accuracy of 0.3103939250118652, and log loss of 1.0994688999518631. This implies that we were better off guessing class 1 all the time because then, we would be right 35.45% of the time. Confusion Matrix plot showed that the model predicted every row as class 0 or "Low Spenders" which reflected on the recall, precision, and f1-scores of each classification (with class 0 being the only one with scores that are not 0).
#
# In light of the terrible result, chi-square tests (for categorical) and Kruskal tests (for continous; it is nonparametric) was done against the response variable `Customer Segmentation`. As expected, every tests indicated that each features are independent of the response variable. This explained the lack of predictive power of the model and thus the terrible result that's not even better than guessing randomly.
#
# The feauture importance table showed the coeficients of each predictors for each modal. All but two are 0. Even the two that were not, are practically 0 themselves. This further supported the independence of features from response.
#
# In an attempt to make the best out of the limited dataset, a feauture engineering was done. The following features was added:
# * spend/income - spending of the customer raltive to their anual income
# * average_spent_last_6_months - the name speaks for itself.
# * 1_year_spending_proportion_phase - like the spend/income but in the context of a year.
#
# The dataset was also clustered (using Kmeans) by the following variables:
# * Age - 3 clusters
# * Annual Income (K$) - 4 clusters
# * Average Spend per Visit ($) - 3 clusters
#
# And then interaction features was added by multiplying each cluster of each the three column. Then multicorrelation was resolved by ranking their importance on another fitted logistic regression.
#
# Even with all the features added, the results were no different than the simple ones. Even the hyperparameter tuning of a Random Forest brought simillar horrible results.
#
# In conclusion, the independence of the features from the response ensued to a below the baseline model. This goes to show that if the dataset is trash, the model will also be garbage. Perhaps other features should be added. Features that are more related to the customer segmentation. Or perhaps the problem is in the customer segmentation itself. How do they even calculate for that in the first place? My recommendation is to scrap the response variable and conduct a cluster analysis based on the features. Upon doing so, it will brought about more natural groupings among the customers.
